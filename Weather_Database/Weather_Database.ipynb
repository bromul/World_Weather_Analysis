# %%
# Import Dependencies
import pandas as pd
import numpy as np 
import requests 
from citipy import citipy

# Import Weather API key
from config import weather_api_key

# %%
# Create set of random latitude and longitude combinations
lats = np.random.uniform(-90, 90, size = 2000)
lngs = np.random.uniform(-180, 180, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add coordinates to a list
coordinates = list(lat_lngs)

# %%
# Create list to hold the cities
cities = []

# Identify closest city to each coordinate
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # Append unique cities to list
    if city not in cities:
        cities.append(city)

# Confirm sufficient count
len(cities)
# Out:
# 745

# %%
# Build URL for OpenWeatherMap
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key

# %%
# Create an empty list to import city data
city_data = []

# Print the beginning of data logging
print('Beginning Data Retrieval')
print('------------------------')

# Create counters
record_count = 1
set_count = 1

# Loop through cities in our list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0) & (i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint url with each city
    city_url = url + '&q=' + city.replace(' ', '+')

    # Log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')

    # Add one to record count
    record_count += 1

    # Run an API request for each of the cities
    # Use try-except in case city isn't found
    try:
        # Parse JSON and retrieve data
        city_weather = requests.get(city_url).json()

        ## Parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_desc = city_weather['weather'][0]['description']


        # Append city information into city_data list
        city_data.append({
            'City': city.title(),
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Country': city_country,
            'Current Description': city_desc,
        })
    except:
        print(f'{city} not found. Passing...')
        pass
    
# Indicate that data loading is complete
print('-----------------------')
print('Data Retrieval Complete')
print('-----------------------')
# Out:
# --------------
# Processing Record 24 of Set 12 | sao gabriel da cachoeira
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 25 of Set 12 | gizo
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 26 of Set 12 | calama
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 27 of Set 12 | mayo
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 28 of Set 12 | umzimvubu
# umzimvubu not found. Passing...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 29 of Set 12 | almaznyy
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 30 of Set 12 | barbar
# barbar not found. Passing...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 31 of Set 12 | praia
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 32 of Set 12 | dolores
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 33 of Set 12 | mucurapo
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 34 of Set 12 | casa nova
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 35 of Set 12 | comodoro rivadavia
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 36 of Set 12 | masasi
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 37 of Set 12 | mumford
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 38 of Set 12 | lexington
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 39 of Set 12 | naze
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 40 of Set 12 | bucerias
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 41 of Set 12 | houma
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 42 of Set 12 | nizhnevartovsk
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 43 of Set 12 | bollnas
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 44 of Set 12 | beni
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 45 of Set 12 | nara
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 46 of Set 12 | xinpu
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 47 of Set 12 | yokadouma
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 48 of Set 12 | mnogovershinnyy
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 49 of Set 12 | atambua
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 50 of Set 12 | san nicolas
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 1 of Set 13 | uglekamensk
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 2 of Set 13 | tommot
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 3 of Set 13 | along
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 4 of Set 13 | muros
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 5 of Set 13 | homer
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 6 of Set 13 | vodnyy
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 7 of Set 13 | bom jesus
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 8 of Set 13 | half moon bay
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 9 of Set 13 | autazes
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 10 of Set 13 | morant bay
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 11 of Set 13 | mariental
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 12 of Set 13 | vao
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 13 of Set 13 | riyadh
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 14 of Set 13 | puerto quijarro
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 15 of Set 13 | douglas
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 16 of Set 13 | gweta
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 17 of Set 13 | asau
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 18 of Set 13 | sao bartolomeu de messines
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 19 of Set 13 | korla
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 20 of Set 13 | gameleira
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 21 of Set 13 | grand gaube
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 20 of Set 15 | gold coast
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 21 of Set 15 | zapolyarnyy
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 22 of Set 15 | srednekolymsk
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 23 of Set 15 | imisli
# imisli not found. Passing...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 24 of Set 15 | were ilu
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 25 of Set 15 | villazon
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 26 of Set 15 | freeport
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 27 of Set 15 | haian
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 28 of Set 15 | severnyy
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 29 of Set 15 | marrakesh
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 30 of Set 15 | le vauclin
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 31 of Set 15 | aswan
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 32 of Set 15 | tilichiki
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 33 of Set 15 | svelgen
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 34 of Set 15 | jieznas
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 35 of Set 15 | cockburn town
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 36 of Set 15 | corrente
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 37 of Set 15 | redlands
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 38 of Set 15 | zakharovo
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 39 of Set 15 | newcastleton
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 40 of Set 15 | collie
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 41 of Set 15 | bur gabo
# bur gabo not found. Passing...
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 42 of Set 15 | guarapari
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 43 of Set 15 | lawton
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 44 of Set 15 | ardakan
# -----------------------
# Data Retrieval Complete
# -----------------------
# Processing Record 45 of Set 15 | vestmannaeyjar
# -----------------------
# Data Retrieval Complete
# -----------------------

# %%
# Convert array of dictionaries into pandas dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Codrington -38.2667  141.9667     51.19        95          12
# 1            Aykino  62.2248   49.9922     24.94        78          12
# 2            Hobart -42.8794  147.3294     55.40        58         100
# 3             Ancud -41.8697  -73.8203     53.60       100          90
# 4            Artyom  40.4723   50.3330     55.40        76           0
# ..              ...      ...       ...       ...       ...         ...
# 684          Collie -33.3667  116.1500     50.00        88         100
# 685       Guarapari -20.6667  -40.4975     84.20        70          20
# 686          Lawton  34.6087  -98.3903     64.99        31          20
# 687         Ardakan  32.3100   54.0175     69.80        24           0
# 688  Vestmannaeyjar  63.4427  -20.2734     33.80        93          90
#
#      Wind Speed Country Current Description
# 0          9.55      AU          few clouds
# 1          3.11      RU          few clouds
# 2         11.50      AU     overcast clouds
# 3          8.05      CL          light rain
# 4          9.22      AZ           clear sky
# ..          ...     ...                 ...
# 684        3.31      AU     overcast clouds
# 685       13.80      BR          few clouds
# 686       16.11      US          few clouds
# 687        2.30      IR           clear sky
# 688       26.46      IS                snow
#
# [689 rows x 9 columns]

# %%
# Rearrange columns
new_col_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_col_order]

# Check that columns have been rearranged
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Codrington      AU -38.2667  141.9667     51.19        95          12
# 1        Aykino      RU  62.2248   49.9922     24.94        78          12
# 2        Hobart      AU -42.8794  147.3294     55.40        58         100
# 3         Ancud      CL -41.8697  -73.8203     53.60       100          90
# 4        Artyom      AZ  40.4723   50.3330     55.40        76           0
# 5          Jalu      LY  29.0331   21.5482     83.80        27         100
# 6        Visnes      NO  59.3556    5.2242     50.00        57           0
# 7     Zaozhuang      CN  34.8647  117.5542     48.74        53           6
# 8       Lerwick      GB  60.1545   -1.1494     44.60        87           0
# 9  Saint George      US  37.1041 -113.5841     68.00        16           1
#
#    Wind Speed Current Description
# 0        9.55          few clouds
# 1        3.11          few clouds
# 2       11.50     overcast clouds
# 3        8.05          light rain
# 4        9.22           clear sky
# 5       22.77     overcast clouds
# 6        8.05           clear sky
# 7        2.95           clear sky
# 8       11.50           clear sky
# 9        4.61           clear sky

# %%
# Create output file (CSV)
output_data_file = 'Weather_Database/WeatherPy_Database.csv'

# Export city data to a CSV
city_data_df.to_csv(output_data_file, index_label= 'City_ID')
